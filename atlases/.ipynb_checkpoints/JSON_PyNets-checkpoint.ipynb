# %%
import os
from os.path import isfile, join
from pathlib import Path
import numpy as np
from nibabel.testing import data_path
import nibabel as nib
import json
import pdb
import glob
from nilearn import plotting as nip
from nilearn import image
import pandas as pd

# %% [markdown]
# Finds all the PyNets atlases. Want to remove file extension since this will be used to load the Nifti file and write to the JSON file with the same name.

# %%
mypath = str(Path().absolute())
labelpath = join(mypath,'PyNets/Labels')
label_files = [f for f in os.listdir(labelpath) if os.path.isfile(join(labelpath,f))]
files = [f.split('.')[0] for f in label_files]
files = [i for i in files if not i.startswith("__")]
files = [i for i in files if not i.startswith("aal_c")]
files = [i for i in files if not i.startswith("Random")]
files = [i for i in files if not i.startswith("Voxel")]
#files = files[0:5]
files
# Out:
# ['destrieux2009_rois',
#  'HarvardOxfordThr252mmWholeBrainMakris2006',
#  'Juelichgmthr252mmEickhoff2005',
#  'Hammers_mithAtlasn30r83Hammers2003Gousias2008',
#  'CorticalAreaParcellationfromRestingStateCorrelationsGordon2014',
#  'DesikanKlein2012',
#  'AALTzourioMazoyer2002',
#  'AICHAreorderedJoliot2015',
#  'AAL2zourioMazoyer2002',
#  'AICHAJoliot2015',
#  'MICCAI2012MultiAtlasLabelingWorkshopandChallengeNeuromorphometrics',
#  'BrainnetomeAtlasFan2016']

# %% [markdown]
# For each atlas, load in the metadata file currently in .txt format from PyNets. Then create a JSON file with this basic information: the labels for each region. Load in the Nifti file and calculate the size per region

# %%
for f in files:
    print(f)
    try:
        filename = str(f)+'.txt'
        filename = join(labelpath,filename)
        df = pd.read_csv(filename, sep=' ', header=None, usecols=[0,1])
        df.columns = ["Region", "Label"]
    except ValueError:
        filename = str(f)+'.txt'
        filename = join(labelpath,filename)
        df = pd.read_csv(filename, sep='\t', header=None, usecols=[0,1])
        df.columns = ["Region", "Label"]
    outname = f+'.json'
    jsonpath = join(mypath,'PyNets/JSONs')
    outname = join(jsonpath,outname)
    #print(df)
    #createJSON(df,outname)
    
    niftipath = join(mypath,'PyNets/atlases/')
    niftiname = f+'.nii.gz'
    niftiname = join(niftipath,niftiname)
    Size_JSON(outname, niftiname)
# Out:
# destrieux2009_rois
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-72946b4e794b> in <module>
#      20     niftiname = f+'.nii.gz'
#      21     niftiname = join(niftipath,niftiname)
# ---> 22     Size_JSON(outname, niftiname, outname)
#      23
#
# NameError: name 'Size_JSON' is not defined

# %% [markdown]
# Creates a JSON file. df is a pandas dataframe with columns "Region" (the region number) and "Label" (the corresponding label for the region). Puts the data into JSON format.

# %%
def createJSON(df, outname):
    data = {}
    data['0'] = {}
    data['0']['label'] = 'empty'
    print(type(data))
    for idx, row in df.iterrows():
        data[str(row['Region'])]={}
        data[str(row['Region'])]['label'] = row['Label']
    with open(outname, 'w') as outfile:  
        json.dump(data, outfile, indent=4, sort_keys=True)

# %% [markdown]
# Calculates the size of each region in an atlas. json_file is the name of the current JSON_file. nifti_file is name of the Nifti_file. outname is the name of the JSON_file where the Size data should be added. The default for outname is the json_file.

# %%
def Size_JSON(json_file, nifti_file):
    img = nib.load(nifti_file)
    dat = img.get_data()
    dat = np.squeeze(dat)
    labs = np.unique(dat)
    #labs = labs[labs != 0]
    #print(labs)
    sizes = []
    for lab in labs:
        fd_dat = np.asarray(dat == lab).astype('float64')
        parcels = nib.Nifti1Image(dataobj=fd_dat, header=brain.header, affine=brain.affine)
        #regions_imgs = image.iter_img(parcels)
        # compute the centers of mass for each ROI
        size = sum(parcels)/lab
        sizes.append(size)
    parcel_sizes = dict(zip(labs, sizes))
    
    with open(json_file) as js:
            js_contents = json.load(js)
            for region, center in parcel_sizes.items():
                region = int(region)
                if str(region) in js_contents:
                    js_contents[str(region)]["center"] = center
                else:
                    js_contents[str(region)]={}
                    js_contents[str(region)]["label"] = 'NULL'
                    js_contents[str(region)]["center"] = center
            with open(json_file, 'w') as jso:
                json.dump(js_contents, jso, indent=4)
    #img = nib.load(nifti_file)
    #img_data = img.get_fdata()
    #img_flat = img_data.flatten()
    #img_flat.tolist()
    #img_flat = [int(i) for i in img_flat]
    #values = np.unique(img_flat)
    #counts = np.array(range(1, len(img_flat)+1))
    #counts = [int(i) for i in counts]
    #img_flatten = list(zip(img_flat, counts))
    #img_flatten = sorted(img_flatten, key = lambda l:l[0])

    #img_cell = [[] for i in range(len(values))]
    #start = 0
    #for i in range(0,len(values)):
    #    img_list = [x[0] for x in img_flatten]
    #    end = max(loc for loc, val in enumerate(img_list) if val == values[i])
    #    for j in range(start,end):
    #        img_cell[i].append(img_flatten[j][1])  
    #    start = end+1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-ce3c8292dcc0> in <module>
# ----> 1 def Size_JSON(json_file, nifti_file, outname=json_file):
#       2     img = nib.load(nifti_file)
#       3     dat = img.get_data()
#       4     dat = np.squeeze(dat)
#       5     labs = np.unique(dat)
#
# NameError: name 'json_file' is not defined

# %% [markdown]
# Calculates the center of mass for each region in a Nifti file. brain is the nibabel object after loading the Nifti file.

# %%
def get_centers(brain, outfile):
    """
    Get coordinate centers given a nifti image loaded with nibabel
    
    Returns a dictionary of label: coordinate as an [x, y, z] array
    """
    dat = brain.get_data()
    dat = np.squeeze(dat)
    labs = np.unique(dat)
    labs = labs[labs != 0]
    #print(labs)
    coords_connectome = []
    for lab in labs:
        fd_dat = np.asarray(dat == lab).astype('float64')
        parcels = nib.Nifti1Image(dataobj=fd_dat, header=brain.header, affine=brain.affine)
        #regions_imgs = image.iter_img(parcels)
        # compute the centers of mass for each ROI
        coords = nip.find_xyz_cut_coords(parcels)
        coords_connectome.append(coords)

    
    return dict(zip(labs, coords_connectome))

# %% [markdown]
# For each JSON file, add the centers to each region

# %%
def main():
    for f in files:
        print(f)
        filename = f+'.json'
        jsonpath = join(mypath, 'PyNets/JSONs')
        outfile = join(jsonpath,filename)
        niftipath = join(mypath,'PyNets/atlases/')
        niftiname = f+'.nii.gz'
        niftiname = join(niftipath,niftiname)
        parcel_im = nib.load(niftiname)
        #get_centers(parcel_im,outfile)
        parcel_centers = get_centers(parcel_im,outfile)
        print(parcel_centers)
        
        with open(outfile) as js:
            js_contents = json.load(js)
            #for (k, v) in js_contents.items():
                #try:
            #        js_contents[k]["center"] = parcel_centers[int(k)]
            #    except KeyError:
            #        js_contents[k]["center"] = None
            #        with open(outfile, 'w') as jso:
            #            json.dump(js_contents, jso, indent=4)
            for region, center in parcel_centers.items():
                region = int(region)
                if str(region) in js_contents:
                    js_contents[str(region)]["center"] = center
                else:
                    js_contents[str(region)]={}
                    js_contents[str(region)]["label"] = 'NULL'
                    js_contents[str(region)]["center"] = center
            with open(outfile, 'w') as jso:
                json.dump(js_contents, jso, indent=4)
    return parcel_centers

# %%
x = 4.0
int(x)
# Out:
# 4

# %%
main()
# Out:
# destrieux2009_rois
# {1: [-23.34529147982063, 56.699551569506724, -8.156950672645742], 2: [41.695205479452056, -78.33219178082192, -11.154109589041099], 3: [-1.1527599486521183, -33.40051347881899, 68.7586649550706], 4: [-56.27060270602706, -11.32226322263223, 15.58425584255842], 5: [16.047524752475255, 63.19405940594061, 1.5128712871287178], 6: [8.572307692307689, 38.72307692307692, 8.57846153846154], 7: [0.89196675900277, 16.087719298245617, 36.2253000923361], 8: [0.2699275362318758, -10.686594202898547, 42.47826086956522], 9: [0.0895104895104879, -39.033566433566435, 32.62657342657343], 10: [8.156862745098039, -50.068627450980394, 7.647058823529406], 11: [0.605657237936768, -80.36272878535775, 18.92678868552413], 12: [-50.0961038961039, 11.667532467532467, 10.319480519480521], 13: [-44.16410256410256, 30.487179487179475, -9.220512820512823], 14: [52.192660550458726, 28.79816513761469, 8.477064220183479], 15: [39.664900662251654, 29.643708609271528, 33.92317880794701], 16: [-9.864442679375173, 25.48133439237489, 46.88747683346571], 17: [-38.476489028213166, -7.877742946708466, 0.551724137931032], 18: [-37.054704595185996, 9.669584245076578, -2.481400437636765], 19: [40.93410404624278, -81.28670520231213, 14.610404624277464], 20: [19.051724137931032, -85.20977011494253, 32.94252873563218], 21: [-34.64544456641054, -53.9549945115258, -18.768386388583977], 22: [-10.890959925442687, -72.39235787511649, -4.808946877912398], 23: [-22.812928501469145, -18.8413320274241, -24.538687561214495], 24: [28.477669902912623, 34.66731391585762, -16.83236245954693], 25: [-42.93521126760564, -67.09953051643193, 37.58685446009389], 26: [57.656373713380844, -32.3507521773555, 32.23911322248614], 27: [-21.436643835616437, -60.60616438356165, 58.77397260273972], 28: [-44.62390158172232, -24.76625659050967, 54.72583479789104], 29: [42.1107099879663, -7.896510228640196, 51.5439229843562], 30: [0.16348289649045, -58.53442914260329, 42.813860506441586], 31: [-5.060921248142648, 38.352154531946496, -19.081723625557203], 32: [5.370786516853926, 14.528089887640448, -12.224719101123597], 33: [-47.513513513513516, -19.405405405405403, 7.081081081081081], 34: [-58.21836587129429, -11.694143167028201, -4.900939985538685], 35: [-40.473846153846154, 4.1200000000000045, -19.587692307692308], 36: [-57.241217798594846, -37.814988290398134, 17.526932084309138], 37: [-51.54983922829582, -34.40192926045016, -25.636655948553056], 38: [61.32610082961071, -28.072112316528404, -12.280791320995533], 39: [41.45614035087719, 28.36842105263159, 2.701754385964918], 40: [-43.26126126126126, 21.45045045045046, 8.090090090090087], 41: [40.52673267326733, -27.81584158415842, 18.415841584158414], 43: [17.79278445883442, -95.70490286771508, -1.5911193339500471], 44: [37.522222222222226, 7.666666666666671, -36.51481481481481], 45: [-16.333825701624818, -67.08567208271788, 5.536189069423926], 46: [-36.29158878504673, -20.444859813084108, 46.127102803738325], 47: [13.055319148936164, -36.306382978723406, 48.02553191489362], 48: [31.831775700934585, 22.85046728971963, -6.112149532710276], 49: [-40.91104294478528, -12.546012269938643, -6.579754601226995], 50: [-35.740432612312816, 6.237936772046595, 11.427620632279542], 51: [-40.72592592592593, -21.851851851851848, -25.696296296296296], 52: [26.16216216216216, -78.05405405405406, -7.810810810810807], 53: [-39.358870967741936, 23.22983870967741, 22.032258064516128], 54: [28.879807692307693, 41.798076923076934, 22.0], 55: [-23.932489451476798, 19.0928270042194, 44.82981715893108], 56: [-50.60377358490566, -52.660377358490564, 31.509433962264154], 57: [-29.130769230769232, -59.97435897435898, 39.851282051282055], 58: [-30.786729857819907, -86.74407582938389, 4.407582938388629], 59: [28.220994475138127, -76.98895027624309, 22.983425414364646], 60: [-43.26086956521739, -68.79710144927536, 2.318840579710141], 61: [-43.11557788944724, -51.49246231155779, -13.437185929648237], 62: [-28.91417910447761, -49.5, -10.421641791044777], 63: [-40.69767441860465, 41.534883 ...
# HarvardOxfordThr252mmWholeBrainMakris2006
# {1: [-24.930634201585505, 53.00254813137033, 7.510192525481315], 2: [26.12439379243453, 52.202958292919504, 8.196653734238595], 3: [-36.7051724137931, 1.4431034482758633, -0.17241379310344485], 4: [37.56477561388654, 2.574089754445396, -0.3251481795088864], 5: [-13.864511162432635, 19.02848344880678, 56.51886066204773], 6: [14.69800332778702, 18.868552412645585, 57.12978369384359], 7: [-38.32087114337568, 18.58511796733211, 42.339019963702356], 8: [39.36977743069113, 18.76298320968371, 43.03319016009371], 9: [-49.99341021416804, 28.57001647446458, 8.803953871499175], 10: [52.310483870967744, 28.0, 7.762096774193552], 11: [-50.927297668038406, 14.751714677640592, 15.31138545953361], 12: [52.406106870228996, 15.47786259541985, 16.149618320610685], 13: [-33.700549450549445, -11.668040293040292, 49.497252747252745], 14: [34.85369968667149, -10.59098577970596, 50.23138105567607], 15: [-40.62723404255319, 11.14382978723404, -29.702978723404257], 16: [40.70055061414655, 13.069038542990256, -29.833968657348578], 17: [-56.1897233201581, -3.652173913043484, -8.324110671936758], 18: [57.67164179104478, -0.5074626865671661, -10.238805970149258], 19: [-60.64538198403649, -27.36374002280502, 2.364880273660205], 20: [60.30849947534102, -23.292759706190978, 1.5760755508919146], 21: [-57.61434977578475, -4.044843049327355, -22.3542600896861], 22: [57.905472636815915, -1.3084577114427844, -24.701492537313435], 23: [-61.31338582677165, -27.285039370078735, -11.543307086614178], 24: [61.49482071713146, -22.390438247011957, -12.7808764940239], 25: [-57.842907385697536, -53.0715123094959, 0.834701055099643], 26: [58.4066029539531, -49.15899218071243, 1.5377932232840976], 27: [-48.29090909090909, -5.078787878787878, -39.35151515151515], 28: [46.32807570977917, -2.391167192429023, -41.261829652996845], 29: [-53.66197183098592, -28.607645875251507, -26.02012072434608], 30: [53.594508975712785, -23.43822597676875, -28.261879619852166], 31: [-51.9367816091954, -53.47701149425288, -16.59770114942529], 32: [54.23772609819122, -49.84754521963825, -16.813953488372093], 33: [-38.5477109762824, -27.745173745173744, 51.854384997242136], 34: [37.99938385705484, -26.171287738755396, 52.55514479359212], 35: [-29.380262249827467, -49.552795031055894, 57.65217391304347], 36: [29.292666209732687, -47.771076079506514, 59.07607950651132], 37: [-56.92811839323467, -32.79492600422833, 37.295983086680764], 38: [58.545226130653276, -27.1105527638191, 37.917085427135675], 39: [-54.874524714828894, -46.20342205323195, 33.439163498098864], 40: [55.28914664457332, -40.46561723280861, 33.824357912178954], 41: [-50.39029535864979, -55.68143459915612, 29.9746835443038], 42: [52.05475701574264, -51.827515400410675, 32.365503080082135], 43: [-32.16350423899879, -72.87686717803794, 38.020589422688744], 44: [33.037313432835816, -71.11194029850746, 38.98341625207297], 45: [-45.18003913894324, -75.61643835616438, -2.0009784735812133], 46: [45.61271393643031, -73.99804400977995, -1.6841075794621077], 47: [-10.05263157894737, -74.94736842105263, 8.114551083591337], 48: [11.888130968622107, -73.45429740791269, 8.455661664392906], 49: [-5.025522041763338, 43.55916473317865, -18.31090487238979], 50: [4.438461538461539, 43.07307692307691, -18.823076923076925], 51: [-4.755319148936167, -2.558510638297875, 56.545212765957444], 52: [6.135021097046419, -2.627285513361457, 57.67088607594937], 53: [-5.005586592178773, 20.44320297951583, -14.953445065176908], 54: [4.585964912280701, 21.09824561403508, -15.249122807017542], 55: [-5.708827404479578, 36.68642951251647, 21.470355731225297], 56: [6.6724511930585635, 36.688358640636295, 22.572668112798254], 57: [-3.647149460708789, 17.742681047765785, 24.802773497688747], 58: [5.392125984251976, 19.113385826771662, 24.025196850393698], 59: [-4.958367346938772, -37.06122448979592, 30.25632653061224], 60: [6.631944444444443, -35.89756944444444, 30.177083333333343], 61: [-7.094339622641513, -60.22351233671989, 37.60957910014514], 62: [8.94404591104734, -58 ...
# Juelichgmthr252mmEickhoff2005
# {1: [-36.57556935817806, -49.2463768115942, 38.58799171842651], 2: [38.12456747404843, -47.5916955017301, 37.564013840830455], 3: [-45.17299578059072, -40.15189873417722, 41.38396624472574], 4: [43.28070175438597, -38.859649122807014, 46.6140350877193], 5: [-30.86231884057971, -51.18115942028986, 44.83333333333333], 6: [33.88996763754045, -51.46925566343042, 47.13268608414239], 7: [-23.684210526315795, -9.649122807017548, -7.543859649122808], 8: [26.746268656716424, -9.104477611940297, -7.432835820895519], 9: [-26.36190476190476, -4.7873015873015845, -22.86349206349206], 10: [29.87172011661808, -3.1720116618075735, -23.137026239067055], 11: [-18.191919191919197, -4.121212121212125, -15.565656565656568], 12: [21.492227979274617, -3.0051813471502555, -13.305699481865283], 13: [-50.802872062663184, 12.180156657963437, 19.328981723237604], 14: [53.94459833795014, 12.361957525392427, 17.200369344413673], 15: [-51.14545454545454, 28.24545454545455, 14.656363636363636], 16: [52.91402013942681, 27.745933384972886, 11.646785437645235], 17: [-28.18610747051114, -25.287024901703802, -12.20707732634338], 18: [29.943209876543207, -23.01234567901234, -11.822222222222223], 19: [-22.60910518053376, -8.16326530612244, -33.46938775510204], 20: [24.09947643979058, -4.900523560209422, -33.096858638743456], 21: [-24.285714285714292, -32.14285714285714, -4.828571428571422], 22: [24.901408450704224, -30.535211267605632, -3.4929577464788792], 23: [-19.0, -12.0, -10.0], 24: [18.0, -10.0, -10.0], 25: [-19.001862197392924, -27.57914338919926, -14.234636871508378], 26: [20.80952380952381, -25.6959706959707, -14.16117216117216], 27: [-57.81963927855711, -38.625250501002, 34.51102204408818], 28: [61.64192139737992, -33.2052401746725, 31.63100436681222], 29: [-48.443835616438356, -37.79178082191781, 22.54794520547945], 30: [50.8930817610063, -32.71069182389937, 25.15094339622641], 31: [-52.556291390728475, -51.70419426048565, 39.06843267108168], 32: [54.62558139534883, -44.91162790697675, 38.051162790697674], 33: [-56.68100358422939, -25.73476702508961, 24.89605734767025], 34: [54.7871485943775, -20.714859437751002, 28.48192771084338], 35: [-51.593582887700535, -24.556149732620327, 34.92513368983957], 36: [52.98461538461538, -24.969230769230762, 40.46666666666667], 37: [-44.76962676962677, -60.8931788931789, 38.96525096525096], 38: [51.3924977127173, -55.006404391582805, 34.24153705397987], 39: [-41.98771121351767, -74.10291858678956, 30.11827956989248], 40: [45.807544264819086, -70.68360277136259, 30.65434949961508], 41: [-48.42718446601942, -20.262135922330103, 6.572815533980588], 42: [50.64516129032259, -13.846774193548384, 6.032258064516128], 43: [-40.16969696969697, -30.4969696969697, 10.824242424242428], 44: [41.074074074074076, -26.086419753086417, 11.037037037037038], 45: [-53.850746268656714, -8.522388059701498, 1.746268656716424], 46: [56.5, -2.239999999999995, 1.5400000000000063], 47: [-6.62740384615384, -32.46634615384616, 65.19711538461539], 48: [16.61739130434782, -27.936956521739134, 64.0], 49: [-36.146627565982406, -20.21114369501467, 46.739002932551315], 50: [36.69736842105263, -20.328947368421055, 47.75], 51: [-44.391011235955055, -25.923595505617982, 56.37528089887641], 52: [46.037602820211504, -24.9165687426557, 56.777908343125745], 53: [-39.54761904761905, -34.81904761904762, 51.292857142857144], 54: [36.91328210757409, -34.79253567508232, 52.78155872667398], 55: [-34.83084577114428, -22.09950248756219, 39.442786069651746], 56: [33.032745591939545, -22.30226700251889, 41.38539042821159], 57: [-49.497175141242934, -14.655367231638422, 37.37288135593221], 58: [39.78898007033996, -22.243845252051585, 47.01289566236811], 59: [-51.742251223491024, -22.946166394779766, 17.51386623164764], 60: [51.939047619047614, -21.93142857142857, 18.971428571428575], 61: [-34.984848484848484, -23.318181818181813, 19.318181818181813], 62: [35.7375, -20.3125, 18.75], 63: [-39.266881028938904, -12.045016077170416, 17.40192926045016], 64: [41.506756756756744,  ...
# Hammers_mithAtlasn30r83Hammers2003Gousias2008
# {1: [27.097862391449567, -16.756847027388105, -18.168002672010687], 2: [-26.160734357437235, -18.528287748220308, -17.841513675533903], 3: [22.58747903856903, -3.6903297931805525, -20.892118501956404], 4: [-22.35036496350365, -5.300312825860274, -20.799270072992698], 5: [30.29671983147758, 8.807001705286382, -36.36824154880129], 6: [-30.589399068980114, 7.361299195937363, -36.217731696995344], 7: [48.834673648775016, 8.263886291378356, -34.34654946699084], 8: [-49.15739078396169, 5.603231597845593, -33.77737881508079], 9: [23.86228777225176, -16.466815297547583, -26.0154347453267], 10: [-23.782060027285127, -18.048772169167805, -25.638472032742158], 11: [52.63761804826862, -14.53677859391395, -1.8884575026232966], 12: [-51.092764886164616, -17.094297285464094, -1.765105078809114], 13: [54.19701589624751, -15.106354433467487, -23.284628206691877], 14: [-53.7078204965529, -17.20297762551283, -22.648267986296155], 15: [34.40207433016422, -15.265168539325842, -32.233880726015556], 16: [-34.5182873981626, -17.097590570289483, -30.720575489686254], 17: [22.935940007131393, -60.942458548760925, -36.88632109110358], 18: [-22.21195234012619, -61.15974191562796, -36.96401327793532], 19: [0.5013179966450991, -29.584471603163195, -29.99904145698538], 20: [-32.512759827124924, -2.4173698291829595, 0.7834945462029168], 21: [33.82036020319154, 0.008517625327101541, 0.20334547693570926], 22: [-29.26662349255247, -81.24274937426706, 7.807571806136565], 23: [31.54792189487435, -78.54840317645845, 9.198975557770979], 24: [-4.984364881117585, 24.336941437690825, 23.02053844018873], 25: [5.935815868263475, 22.904004491017957, 24.1971369760479], 26: [-4.9252031001961, -29.58744980857223, 33.91810626575777], 27: [5.877402446126965, -27.67326732673267, 34.756066783148896], 28: [-32.04846276343916, 28.009569172058605, 25.90693370443165], 29: [33.14724814481673, 30.91208961097368, 24.59350404767258], 30: [-44.267385251640434, -48.414298972597166, -2.942198414119872], 31: [45.937768476704484, -45.60776045190629, -2.745897125234052], 32: [-46.477716871138966, -45.8654833376838, 32.9950926651005], 33: [48.570993349813726, -41.80211343616169, 34.07292573378365], 34: [-13.012431444241315, 8.947349177330892, 9.09031078610603], 35: [13.799750133856861, 9.989291451008398, 9.530430126717832], 36: [-8.319742489270382, 8.309012875536467, -9.577253218884124], 37: [7.952380952380949, 8.891534391534378, -9.07142857142857], 38: [-24.564319999999995, 1.1556800000000038, -0.030559999999994147], 39: [25.293615624487117, 2.764155588380106, -0.3333333333333286], 40: [-11.07117852975496, -20.017821152010185, 5.633181287790393], 41: [11.998700876908089, -18.946627692973905, 5.801017646421997], 42: [-18.34403391883707, -3.07207752877045, -1.5735917625681424], 43: [19.429940119760474, -2.2251497005988057, -1.6011976047904142], 44: [0.41830770948888585, -5.425901798012134, 16.73431857945873], 45: [14.511532816104008, -13.389809184315368, 14.436254980079681], 46: [-13.174279421622145, -14.083692425548207, 14.280953748922727], 47: [31.669987546699872, -15.846824408468251, -15.753424657534246], 48: [-31.757234726688097, -18.752411575562704, -14.652733118971064], 49: [0.42810188989318476, -11.313886606409199, -4.198849630238286], 50: [-32.38823017513326, -10.558359621451103, 43.02865223539649], 51: [33.922647185217016, -8.557670820799316, 43.100988397077785], 52: [-5.00867908552074, 27.916807790008477, -21.176756985605422], 53: [4.938906752411583, 28.98051825231701, -20.920370720635518], 54: [-24.393585662068148, 48.82054003065676, -13.744251857092323], 55: [24.516383003357646, 49.48836401528308, -14.099455829570452], 56: [-45.62085078955849, 22.190621978730263, 7.763615855623584], 57: [47.576431653470735, 23.0335972518956, 8.094675547735747], 58: [-11.78248533098261, 30.000426985482477, 36.90058125120521], 59: [12.802918417581225, 30.603456951300785, 36.521330559068716], 60: [-36.782426154572335, -23.148088341241646, 41.5498223734877], 61: [36.954166556405305, -21.113895578078285 ...
# CorticalAreaParcellationfromRestingStateCorrelationsGordon2014
# {1.0: [-5.566641509433964, -51.237735849056605, 33.24996226415095], 2.0: [-18.78345250255363, -47.05566905005108, 68.21297242083759], 3.0: [-51.22076092062001, -6.733677782996708, 37.30389854391733], 4.0: [-10.819810326659649, 26.675974710221283, 57.461011591148576], 5.0: [-20.689968930315132, -86.57723035952064, 25.477807367953844], 6.0: [-48.82695252679939, -57.55474732006125, 31.631316998468606], 7.0: [-37.167567567567566, 49.455855855855845, 12.38198198198198], 8.0: [-14.846185737976782, -57.57006633499171, -4.907131011608627], 9.0: [-57.08006814310051, -48.14139693356047, -10.045996592844972], 10.0: [-35.14926931106472, -26.37578288100208, 14.839248434238002], 11.0: [-28.154761904761905, 6.373809523809513, -28.38690476190476], 12.0: [-4.782222222222217, -24.242962962962963, 29.200000000000003], 13.0: [-12.483356449375862, -60.02981969486824, 16.74895977808599], 14.0: [-11.130833970925778, -51.10022953328233, 5.570007651109407], 15.0: [-9.432162708438597, -80.9855987872663, 3.46601819100556], 16.0: [-20.735459662288932, -59.388367729831145, 2.0318949343339625], 17.0: [-10.249201277955265, -58.667731629392975, 3.153354632587863], 18.0: [-28.42965204236006, -34.88350983358548, -8.562783661119518], 19.0: [-19.480243161094222, -39.25531914893617, -2.115501519756833], 20.0: [-14.5, -46.55298913043478, -2.8383152173913118], 21.0: [-12.388650963597428, -33.62312633832977, 44.271591720199865], 22.0: [-7.236821705426351, 0.7965116279069804, 43.66434108527132], 23.0: [-5.70511049723757, 11.04558011049724, 63.379834254143645], 24.0: [-4.714710252600298, 31.72288261515601, 45.84621099554235], 25.0: [-4.838999999999999, 42.760999999999996, 35.959], 26.0: [-1.7807807807807876, -17.959459459459453, 37.83933933933935], 27.0: [-5.5990990990991065, 15.462033462033475, 33.61711711711712], 28.0: [-7.979069767441857, 25.572093023255803, 27.813953488372093], 29.0: [-7.242009132420094, 33.4048706240487, 23.28310502283105], 30.0: [-10.892086330935257, -47.11151079136691, 60.9064748201439], 31.0: [-16.625, -32.644642857142856, 67.63988095238096], 32.0: [-11.080181543116495, -28.90166414523449, 69.6913767019667], 33.0: [-6.743975903614455, -19.954819277108427, 73.96385542168676], 34.0: [-6.657703488372093, -7.688953488372093, 63.853197674418595], 35.0: [-8.83386581469648, -41.23003194888179, 64.60223642172525], 36.0: [-4.21781609195402, -28.568390804597698, 61.12873563218392], 37.0: [-5.585798816568044, -16.64142011834319, 50.36923076923077], 38.0: [-36.95937873357228, -27.331740342493035, 56.698924731182785], 39.0: [-42.45030674846626, -11.966871165644164, 49.51779141104295], 40.0: [-41.26060606060606, -3.7939393939393966, 48.86464646464647], 41.0: [-29.24383561643836, -6.032876712328772, 50.73479452054795], 42.0: [-28.749536178107604, 2.068645640074209, 53.51205936920222], 43.0: [-20.37007874015748, 8.034645669291336, 57.02519685039371], 44.0: [-19.64149443561209, 29.164944356120827, 47.04531001589825], 45.0: [-35.56918547595682, -19.610893032384695, 61.60942100098134], 46.0: [-20.699386503067487, -24.984662576687114, 64.24693251533742], 47.0: [-24.052533992583434, -14.179851668726826, 63.78121137206426], 48.0: [-17.39224137931035, -7.158045977011497, 68.33189655172413], 49.0: [-20.99353169469599, 1.182406209573088, 63.85769728331178], 50.0: [-28.66918918918919, -45.05837837837838, 60.98162162162163], 51.0: [-33.034026465028354, -49.34971644612476, 49.16446124763705], 52.0: [-43.17142857142857, -45.071957671957676, 43.96402116402116], 53.0: [-53.26671476671477, -11.084896584896583, 31.267195767195773], 54.0: [-54.717017208413004, -20.48183556405354, 40.80114722753346], 55.0: [-51.63617677286742, -31.42959917780061, 41.88694758478931], 56.0: [-39.020833333333336, -34.98835784313725, 44.299019607843135], 57.0: [-28.68945868945869, -36.78442545109212, 63.759734093067436], 58.0: [-46.83358778625954, -30.483969465648855, 55.33053435114503], 59.0: [-46.05801526717557, -18.441221374045796, 52.216793893129775], 60.0: [-45.677304964539005, -53.73404255319 ...
# {1.0: [-5.566641509433964, -51.237735849056605, 33.24996226415095],
#  2.0: [-18.78345250255363, -47.05566905005108, 68.21297242083759],
#  3.0: [-51.22076092062001, -6.733677782996708, 37.30389854391733],
#  4.0: [-10.819810326659649, 26.675974710221283, 57.461011591148576],
#  5.0: [-20.689968930315132, -86.57723035952064, 25.477807367953844],
#  6.0: [-48.82695252679939, -57.55474732006125, 31.631316998468606],
#  7.0: [-37.167567567567566, 49.455855855855845, 12.38198198198198],
#  8.0: [-14.846185737976782, -57.57006633499171, -4.907131011608627],
#  9.0: [-57.08006814310051, -48.14139693356047, -10.045996592844972],
#  10.0: [-35.14926931106472, -26.37578288100208, 14.839248434238002],
#  11.0: [-28.154761904761905, 6.373809523809513, -28.38690476190476],
#  12.0: [-4.782222222222217, -24.242962962962963, 29.200000000000003],
#  13.0: [-12.483356449375862, -60.02981969486824, 16.74895977808599],
#  14.0: [-11.130833970925778, -51.10022953328233, 5.570007651109407],
#  15.0: [-9.432162708438597, -80.9855987872663, 3.46601819100556],
#  16.0: [-20.735459662288932, -59.388367729831145, 2.0318949343339625],
#  17.0: [-10.249201277955265, -58.667731629392975, 3.153354632587863],
#  18.0: [-28.42965204236006, -34.88350983358548, -8.562783661119518],
#  19.0: [-19.480243161094222, -39.25531914893617, -2.115501519756833],
#  20.0: [-14.5, -46.55298913043478, -2.8383152173913118],
#  21.0: [-12.388650963597428, -33.62312633832977, 44.271591720199865],
#  22.0: [-7.236821705426351, 0.7965116279069804, 43.66434108527132],
#  23.0: [-5.70511049723757, 11.04558011049724, 63.379834254143645],
#  24.0: [-4.714710252600298, 31.72288261515601, 45.84621099554235],
#  25.0: [-4.838999999999999, 42.760999999999996, 35.959],
#  26.0: [-1.7807807807807876, -17.959459459459453, 37.83933933933935],
#  27.0: [-5.5990990990991065, 15.462033462033475, 33.61711711711712],
#  28.0: [-7.979069767441857, 25.572093023255803, 27.813953488372093],
#  29.0: [-7.242009132420094, 33.4048706240487, 23.28310502283105],
#  30.0: [-10.892086330935257, -47.11151079136691, 60.9064748201439],
#  31.0: [-16.625, -32.644642857142856, 67.63988095238096],
#  32.0: [-11.080181543116495, -28.90166414523449, 69.6913767019667],
#  33.0: [-6.743975903614455, -19.954819277108427, 73.96385542168676],
#  34.0: [-6.657703488372093, -7.688953488372093, 63.853197674418595],
#  35.0: [-8.83386581469648, -41.23003194888179, 64.60223642172525],
#  36.0: [-4.21781609195402, -28.568390804597698, 61.12873563218392],
#  37.0: [-5.585798816568044, -16.64142011834319, 50.36923076923077],
#  38.0: [-36.95937873357228, -27.331740342493035, 56.698924731182785],
#  39.0: [-42.45030674846626, -11.966871165644164, 49.51779141104295],
#  40.0: [-41.26060606060606, -3.7939393939393966, 48.86464646464647],
#  41.0: [-29.24383561643836, -6.032876712328772, 50.73479452054795],
#  42.0: [-28.749536178107604, 2.068645640074209, 53.51205936920222],
#  43.0: [-20.37007874015748, 8.034645669291336, 57.02519685039371],
#  44.0: [-19.64149443561209, 29.164944356120827, 47.04531001589825],
#  45.0: [-35.56918547595682, -19.610893032384695, 61.60942100098134],
#  46.0: [-20.699386503067487, -24.984662576687114, 64.24693251533742],
#  47.0: [-24.052533992583434, -14.179851668726826, 63.78121137206426],
#  48.0: [-17.39224137931035, -7.158045977011497, 68.33189655172413],
#  49.0: [-20.99353169469599, 1.182406209573088, 63.85769728331178],
#  50.0: [-28.66918918918919, -45.05837837837838, 60.98162162162163],
#  51.0: [-33.034026465028354, -49.34971644612476, 49.16446124763705],
#  52.0: [-43.17142857142857, -45.071957671957676, 43.96402116402116],
#  53.0: [-53.26671476671477, -11.084896584896583, 31.267195767195773],
#  54.0: [-54.717017208413004, -20.48183556405354, 40.80114722753346],
#  55.0: [-51.63617677286742, -31.42959917780061, 41.88694758478931],
#  56.0: [-39.020833333333336, -34.98835784313725, 44.299019607843135],
#  57.0: [-28.68945868945869, -36.78442545109212, 63.759734093067436],
#  58.0: [-46.83358778625954, -30.483969465648855, 55.33053435114503],
#  59.0: [-46.05801526717557, -18.441221374045796, 52.216793893129775],
#  60.0: [-45.677304964539005, -53.734042553191486, 13.939716312056731],
#  61.0: [-52.18465227817746, -55.26378896882494, 10.47242206235012],
#  62.0: [-56.119729307652264, -38.26201631094915, 2.280409508936316],
#  63.0: [-57.37934316991909, -40.90575916230367, 34.95573536411233],
#  64.0: [-46.90243902439025, -40.41685144124169, 25.133037694013296],
#  65.0: [-36.60606060606061, -31.658402203856753, 19.382920110192842],
#  66.0: [-54.43940375891121, -20.85936487362281, 6.552819183408943],
#  67.0: [-58.758480325644506, -38.60244233378562, 16.02985074626865],
#  68.0: [-59.605620155038764, -29.53197674418604, 10.680232558139537],
#  69.0: [-41.301587301587304, -36.70039682539682, 13.75],
#  70.0: [-34.43366336633663, -21.411881188118812, 10.623762376237622],
#  71.0: [-40.50709939148073, -13.769438810006761, -3.798512508451651],
#  72.0: [-39.800235710076606, 0.21567472009428457, -11.329404832056568],
#  73.0: [-34.70261437908496, 14.705473856209153, -32.31576797385621],
#  74.0: [-44.21959183673469, 35.84653061224489, 8.458775510204077],
#  75.0: [-51.37234878240377, 21.66928515318145, 11.158680282796539],
#  76.0: [-40.16248839368617, 5.990714948932208, 8.642525533890435],
#  77.0: [-38.141858141858144, -13.689310689310688, 16.134865134865137],
#  78.0: [-39.448377581120944, 49.807276302851534, -7.290560471976406],
#  79.0: [-46.5125748502994, 39.04910179640717, -10.011976047904191],
#  80.0: [-32.93241330502477, 20.357395612172695, -15.272823779193203],
#  81.0: [-36.24852941176471, 2.8544117647058727, 6.710294117647052],
#  82.0: [-37.585808580858085, 9.590759075907584, -0.9504950495049513],
#  83.0: [-32.67355371900827, 17.285123966942137, -7.9669421487603245],
#  84.0: [-32.356880733944955, 22.077064220183473, 5.427981651376143],
#  85.0: [-44.58521870286576, 32.628959276018094, -7.49924585218703],
#  86.0: [-46.5859375, 29.657812500000006, 0.5625],
#  87.0: [-20.15824765310684, -65.97541350022351, 51.85158694680375],
#  88.0: [-26.0007204610951, -68.01873198847262, 34.092219020172905],
#  89.0: [-12.057187017001553, -67.2225656877898, 31.060278207109732],
#  90.0: [-14.619637750238326, -76.47569113441372, 28.098188751191614],
#  91.0: [-9.24792139077853, -54.7233560090703, 60.86923658352231],
#  92.0: [-7.807280513918627, -63.74518201284796, 55.35331905781584],
#  93.0: [-11.245493562231758, -73.86094420600858, 42.343347639484975],
#  94.0: [-39.00039169604387, -74.17822169996083, 38.94320407363885],
#  95.0: [-29.80661157024793, -75.30743801652892, 37.08429752066115],
#  96.0: [-33.80281690140845, -59.373708920187795, 43.4281690140845],
#  97.0: [-32.151766513056835, -86.7284178187404, 11.274961597542244],
#  98.0: [-35.274715660542434, -87.58355205599301, 0.03674540682415284],
#  99.0: [-45.25635359116022, -69.63259668508287, 8.59723756906078],
#  100.0: [-48.70197381278093, -54.670119210474894, -10.320500293140512],
#  101.0: [-59.685754189944134, -5.164804469273747, 10.534916201117312],
#  102.0: [-51.86938775510204, -14.063265306122446, 14.375510204081635],
#  103.0: [-55.49574105621806, -31.098807495741056, 22.314310051107327],
#  104.0: [-52.50121065375303, -22.448748991121874, 18.956416464891035],
#  105.0: [-59.99883040935673, -25.090643274853804, 30.463157894736838],
#  106.0: [-47.18935392117025, 3.6952458350264124, 31.724095895977243],
#  107.0: [-34.88290398126464, 6.4402810304449645, 33.569086651053865],
#  108.0: [-42.83921568627451, 20.30980392156863, 34.32745098039216],
#  109.0: [-42.874653739612185, 23.22506925207756, 24.8123268698061],
#  110.0: [-38.29158110882957, 39.19917864476386, 17.2258726899384],
#  111.0: [-51.781070745697896, 0.36998087954110304, 5.020076481835559],
#  112.0: [-51.60251704247509, 9.468274777136855, 14.171997902464597],
#  113.0: [-41.05252100840336, 8.50210084033614, 22.78781512605042],
#  114.0: [-27.051756007393713, 54.46025878003698, -0.28096118299446005],
#  115.0: [-23.830188679245282, 61.01741654571842, -7.89114658925979],
#  116.0: [-5.367097701149419, 54.898706896551715, -12.050287356321839],
#  117.0: [-6.097028502122498, 36.78047301394784, -8.155245603395997],
#  118.0: [-30.107526881720432, 4.272401433691755, -16.863799283154123],
#  119.0: [-34.91617647058823, 35.97941176470587, -11.186764705882354],
#  120.0: [-22.86926726410121, 30.035846072746438, -17.670005271481287],
#  121.0: [-23.265878877400297, 52.9290989660266, -13.488921713441655],
#  122.0: [-16.24416135881104, 43.658881811748046, -20.682944090587405],
#  123.0: [-11.934108527131784, 24.606589147286826, -18.610465116279073],
#  124.0: [-8.193140794223822, 44.3519855595668, -22.391696750902526],
#  125.0: [-2.9164733178654245, 33.46403712296984, -25.146171693735496],
#  126.0: [-61.019999999999996, -29.510000000000005, -8.823750000000004],
#  127.0: [-57.075260615306384, -12.867276887871853, -14.070938215102977],
#  128.0: [-52.44078232524448, -12.913074972835929, -30.818906193408182],
#  129.0: [-44.874397797660016, 7.378183069511351, -34.85134205092911],
#  130.0: [-31.03404045387272, -34.72570300937346, -16.266403552047365],
#  131.0: [-25.674326986211426, -58.630334865397245, -9.662508207485224],
#  132.0: [-33.7, -63.48888888888889, -15.958333333333336],
#  133.0: [-56.49945593035908, -39.881392818280744, -18.06855277475517],
#  134.0: [-32.59625, -3.3100000000000023, -43.64875],
#  135.0: [-39.439195979899495, -13.888442211055278, -28.316582914572862],
#  136.0: [-33.342258440046564, -43.83352735739231, -21.08498253783469],
#  137.0: [-4.91867954911433, -88.18397745571659, 20.19887278582931],
#  138.0: [-6.859926918392205, -77.79780755176614, -4.813641900121809],
#  139.0: [-41.264828738512946, -73.68253968253968, -7.90142021720969],
#  140.0: [-25.11007667031764, -96.34884994523549, -7.285870755750267],
#  141.0: [-22.157591056617377, -81.02776776054814, -11.225027046520012],
#  142.0: [-21.36872427983539, -14.390123456790121, -25.989300411522635],
#  143.0: [-22.393835616438352, -36.50684931506849, -14.529680365296805],
#  144.0: [-22.430714916151814, -24.032656663724623, -18.756398940864962],
#  145.0: [-14.236071765816803, 47.93106704438148, 39.63361661945231],
#  146.0: [-18.343481138318992, 54.53739245532759, 26.630046326935798],
#  147.0: [-27.507246376811594, 46.913043478260875, 21.397101449275368],
#  148.0: [-20.076782449725783, 62.431444241316285, 2.896709323583181],
#  149.0: [-28.884310618066564, 52.122028526148966, 10.738510301109358],
#  150.0: [-6.8983751846381125, 55.49719350073855, 18.393500738552433],
#  151.0: [-15.046927374301674, 64.73184357541899, 13.288268156424579],
#  152.0: [-5.895152198421641, 42.93461104847802, 7.980834272829767],
#  153.0: [-28.879144385026734, 40.022459893048136, 28.07807486631016],
#  154.0: [-26.279338842975207, 26.67438016528925, 39.22479338842976],
#  155.0: [-37.1505376344086, 33.55436081242533, 32.376344086021504],
#  156.0: [-29.00868486352357, 15.488833746898251, 52.36724565756823],
#  157.0: [-39.009564293305, 15.098299681190213, 49.29755579171095],
#  158.0: [-40.363787375415285, 4.586378737541537, 48.0],
#  159.0: [-50.595628415300546, 9.263661202185801, -18.708333333333336],
#  160.0: [-54.30310262529833, -1.6606205250596702, -2.0286396181384276],
#  161.0: [-58.499133448873486, -18.668977469670708, -2.894280762564989],
#  162.0: [6.39730750287309, -50.215892300114916, 33.230996552290264],
#  163.0: [20.423330197554094, -47.57572906867357, 67.77845719661335],
#  164.0: [50.98703071672355, -5.835494880546079, 37.264846416382255],
#  165.0: [11.207079646017704, 22.86106194690265, 59.7641592920354],
#  166.0: [24.64637681159421, -84.58743961352657, 26.630595813204508],
#  167.0: [49.477855477855485, -42.50466200466201, 44.18414918414919],
#  168.0: [39.607777777777784, 47.60111111111112, 8.39],
#  169.0: [21.9910394265233, -46.52329749103943, -9.358422939068099],
#  170.0: [60.328671328671334, -43.35874125874126, -10.876223776223775],
#  171.0: [35.367777777777775, -20.37444444444445, 13.277777777777771],
#  172.0: [31.874063989108237, 14.370319945541183, -30.631722260040846],
#  173.0: [6.309941520467831, -24.980994152046776, 28.735380116959064],
#  174.0: [13.364240857037316, -53.77761359438493, 12.973402290358337],
#  175.0: [12.776935749588134, -75.83064250411861, 6.139703459637559],
#  176.0: [16.819402985074632, -47.32089552238806, -1.467164179104472],
#  177.0: [14.0748740100792, -56.84161267098632, -4.6385889128869735],
#  178.0: [24.84007707129095, -35.04624277456648, -5.527938342967246],
#  179.0: [18.929184549356222, -30.517167381974247, -10.89914163090129],
#  180.0: [12.124284077892327, -31.837628865979383, 45.735681557846505],
#  181.0: [6.712945590994366, 5.151969981238267, 56.63227016885554],
#  182.0: [6.023274478330663, 26.453451043338674, 47.672552166934196],
#  183.0: [7.467625899280577, 34.25719424460431, 21.59892086330936],
#  184.0: [6.988605534454692, 40.382528486163864, 4.805751492132387],
#  185.0: [6.908830744071949, 5.140228945216677, 39.21095666394113],
#  186.0: [2.8215010141987875, -18.411764705882348, 37.073022312373226],
#  187.0: [8.67462039045553, 11.850325379609558, 46.06290672451193],
#  188.0: [6.087145969498906, 21.218954248366003, 30.2483660130719],
#  189.0: [8.911703239289452, -56.661442006269596, 59.443573667711604],
#  190.0: [18.175496688741717, -32.10485651214128, 67.99337748344371],
#  191.0: [5.231505657093123, -26.352045256745, 65.81201044386424],
#  192.0: [16.7760736196319, 2.0828220858895747, 67.57361963190183],
#  193.0: [10.035602094240843, -41.409424083769636, 66.84712041884816],
#  194.0: [5.640540540540542, -17.024324324324326, 52.691891891891885],
#  195.0: [7.5988023952095745, -9.579341317365277, 50.92814371257485],
#  196.0: [7.225066195939988, -4.508384819064432, 64.91703442188879],
#  197.0: [43.99198717948718, -9.87740384615384, 48.05528846153847],
#  198.0: [41.66534914361, -1.928853754940718, 50.46640316205534],
#  199.0: [30.65868263473054, 1.797904191616766, 51.962574850299404],
#  200.0: [23.44872490504612, 21.435160065111234, 50.224091155724366],
#  201.0: [36.56441393875396, -19.826293558606125, 60.11615628299893],
#  202.0: [20.508883248730967, -24.722081218274113, 65.753807106599],
#  203.0: [30.87453600593912, -6.205642167780255, 51.19970304380104],
#  204.0: [13.03729603729603, -27.42890442890443, 70.55944055944056],
#  205.0: [28.92445328031809, -13.063618290258447, 63.120278330019886],
#  206.0: [17.42886597938144, -17.0, 71.2618556701031],
#  207.0: [21.075702075702083, -5.622710622710628, 65.01831501831501],
#  208.0: [23.107819905213276, 6.437203791469187, 58.57701421800948],
#  209.0: [30.26003210272873, -42.764044943820224, 60.802568218298546],
#  210.0: [34.2695652173913, -40.66956521739131, 51.495652173913044],
#  211.0: [40.17489421720734, -42.76586741889986, 42.593794076163604],
#  212.0: [56.743140243902445, -6.702235772357724, 29.609247967479675],
#  213.0: [40.81933534743203, -31.379456193353477, 43.20422960725075],
#  214.0: [29.484388185654012, -34.8, 63.930801687763704],
#  215.0: [39.812274368231044, -34.142599277978334, 57.442238267148014],
#  216.0: [38.74558710667691, -24.924405218726022, 55.72294704528012],
#  217.0: [49.5751911639762, -25.11639762107052, 53.009345794392516],
#  218.0: [47.64812419146185, -15.406209573091843, 48.830530401034935],
#  219.0: [58.97287299630085, -39.78668310727497, 35.0308261405672],
#  220.0: [51.46284304656183, -53.200740055504156, 28.525439407955602],
#  221.0: [57.88736263736263, -45.38736263736264, 8.343406593406598],
#  222.0: [60.96568627450981, -38.2046568627451, 0.6176470588235361],
#  223.0: [57.302714333002314, -26.664846077457796, 28.41857000993049],
#  224.0: [38.394572025052184, -28.58141962421712, 17.338204592901874],
#  225.0: [62.373322809786885, -26.501973164956595, -6.280189423835836],
#  226.0: [57.81465517241378, -16.423850574712645, -2.7155172413793167],
#  227.0: [55.12529411764706, -15.047058823529412, 6.528823529411767],
#  228.0: [49.41409691629957, -39.352422907488986, 11.845814977973575],
#  229.0: [48.926652892561975, -35.68388429752066, 2.971074380165291],
#  230.0: [58.49926144756279, -38.453471196454956, 14.375184638109303],
#  231.0: [52.314418604651166, -28.079069767441865, 0.31441860465116633],
#  232.0: [62.80555555555554, -23.68402777777777, 1.3177083333333286],
#  233.0: [60.47096260938744, -24.687350835322192, 10.229116945107393],
#  234.0: [40.77896613190731, -12.185977421271545, -3.5086155674390938],
#  235.0: [40.150867823765026, 3.2456608811748993, -14.120827770360478],
#  236.0: [41.745942131263234, 40.68242766407903, 15.040225829216652],
#  237.0: [53.307162534435264, 24.143250688705223, 11.141873278236915],
#  238.0: [38.93272425249168, 6.704318936877087, 10.850498338870437],
#  239.0: [40.20583717357911, -12.132104454685106, 18.10138248847926],
#  240.0: [41.73410757946209, 49.57762836185819, -7.320904645476773],
#  241.0: [47.72389380530973, 38.961061946902646, -10.775221238938052],
#  242.0: [45.59692513368984, 28.85895721925135, -7.421122994652407],
#  243.0: [30.20207612456747, 18.988927335640142, -16.892733564013838],
#  244.0: [37.512, -9.040000000000006, 11.799999999999997],
#  245.0: [39.9453734671126, 10.655518394648823, -2.492753623188406],
#  246.0: [37.16601815823606, 5.808041504539574, 5.595330739299612],
#  247.0: [32.62674961119751, 22.455676516329703, -6.102643856920679],
#  248.0: [34.23664122137404, 21.84541984732823, 2.4446564885496116],
#  249.0: [36.0, 24.516949152542367, 5.769370460048421],
#  250.0: [48.139240506329116, 38.645569620253156, 1.9963833634719776],
#  251.0: [28.654159869494293, -55.56199021207178, 57.21288743882545],
#  252.0: [21.941333333333333, -67.25333333333333, 50.020799999999994],
#  253.0: [32.17086834733894, -66.42717086834733, 34.734593837535016],
#  254.0: [15.046133853151403, -69.41780376868095, 37.823911630929175],
#  255.0: [17.73659117997616, -77.88557806912992, 34.43504171632897],
#  256.0: [8.841924398625423, -85.37972508591065, 32.45876288659794],
#  257.0: [7.6622950819672155, -68.69180327868852, 50.104918032786884],
#  258.0: [36.00178571428572, -78.5169642857143, 23.297321428571422],
#  259.0: [44.140576869224304, -66.7171660599272, 35.25427051246149],
#  260.0: [41.18313953488371, -53.037790697674424, 44.13662790697674],
#  261.0: [35.839215686274514, -56.27843137254902, 44.72156862745098],
#  262.0: [35.37122128174123, -47.951632406287786, 51.42926239419589],
#  263.0: [32.89341240583427, -87.43821125180318, 3.5238018913287306],
#  264.0: [47.62962962962962, -67.1662360034453, 2.239448751076651],
#  265.0: [47.94265620773601, -52.56045442250473, -13.497159859345416],
#  266.0: [57.67806841046277, -53.012072434607646, -1.454728370221332],
#  267.0: [50.07673860911271, -55.24820143884892, 9.541966426858508],
#  268.0: [61.20534458509141, -2.759493670886073, 11.67791842475387],
#  269.0: [55.73478760045924, -12.22962112514351, 15.331802525832373],
#  270.0: [55.005773672055426, -21.83025404157044, 42.19630484988453],
#  271.0: [48.2351945854484, 3.3747884940778476, 38.45093062605753],
#  272.0: [40.36008676789589, 28.251626898047732, 36.684381778741866],
#  273.0: [45.329399141630915, 31.277360515021456, 21.769313304721024],
#  274.0: [50.11790668348044, 4.587641866330387, 4.223833543505677],
#  275.0: [48.85286301038897, 10.581299830877015, 20.60086977530804],
#  276.0: [38.67138810198301, 18.291784702549563, 26.152974504249286],
#  277.0: [26.67978723404255, 58.63351063829788, -5.6345744680851055],
#  278.0: [6.921710526315792, 63.52697368421053, -7.686184210526321],
#  279.0: [6.354334226988385, 46.23994638069706, -11.584450402144775],
#  280.0: [3.9150865622423794, 20.38252267106347, -21.679307502061008],
#  281.0: [35.679966749792186, 36.82709891936824, -11.635910224438902],
#  282.0: [25.067209775967413, 7.737270875763755, -16.40936863543788],
#  283.0: [22.597758405977586, 31.58841843088419, -18.07409713574097],
#  284.0: [20.78566978193146, 50.523987538940816, -16.320872274143298],
#  285.0: [12.402654867256643, 25.55752212389382, -24.02654867256637],
#  286.0: [12.83396226415094, 18.992452830188682, -16.37547169811321],
#  287.0: [9.309116809116816, 38.0591168091168, -22.045584045584043],
#  288.0: [2.739495798319325, 38.45042016806724, -24.90756302521008],
#  289.0: [63.116666666666674, -26.700000000000003, -14.560416666666669],
#  290.0: [57.72341628959276, -8.307409502262445, -17.97652714932127],
#  291.0: [56.31999999999999, -6.612307692307695, -26.63384615384615],
#  292.0: [46.75258748151799, 13.595367175948752, -28.475850172498767],
#  293.0: [29.635321100917437, -46.93348623853211, -6.213302752293572],
#  294.0: [32.56297709923665, -36.58206106870229, -11.770992366412216],
#  295.0: [32.82358490566038, -27.49905660377358, -20.555660377358492],
#  296.0: [23.85365853658537, -22.10694183864915, -22.394934333958723],
#  297.0: [26.451010886469675, -0.5925349922239462, -37.374805598755835],
#  298.0: [26.842660352991828, -63.65992251399053, -10.914334911752043],
#  299.0: [33.9774148714385, -43.43641417651146, -21.011813759555245],
#  300.0: [37.92971246006391, 6.626198083067095, -39.64536741214057],
#  301.0: [51.904040404040416, -10.196969696969703, -35.8125],
#  302.0: [57.190023752969125, -28.420427553444185, -20.29216152019002],
#  303.0: [32.62207670720299, 1.6005612722170213, -44.6623012160898],
#  304.0: [39.66317016317015, -11.919580419580427, -30.50932400932401],
#  305.0: [32.34009009009009, -10.027027027027032, -36.11036036036036],
#  306.0: [43.18210862619807, -24.912140575079874, -22.421725239616613],
#  307.0: [12.687194525904204, -92.16911045943304, 17.344086021505376],
#  308.0: [8.319727891156461, -72.82568027210884, -1.4727891156462647],
#  309.0: [19.976456009913264, -86.90706319702602, -9.019826517967779],
#  310.0: [6.157033805888773, -78.34242093784079, 24.580152671755727],
#  311.0: [13.60504201680672, -69.02521008403362, 21.720288115246092],
#  312.0: [22.25468483816013, -11.94974446337308, -26.28875638841567],
#  313.0: [23.707516339869287, -34.861111111111114, -14.369281045751634],
#  314.0: [30.231958762886592, -18.726804123711347, -19.29639175257732],
#  315.0: [21.18811002661934, 33.69831410825199, 43.568766637089624],
#  316.0: [20.88226299694189, 43.31345565749234, 36.56422018348624],
#  317.0: [24.86944045911048, 51.59540889526542, 25.430416068866577],
#  318.0: [32.08164556962025, 42.048101265822794, 26.248101265822783],
#  319.0: [22.452005730659025, 60.29871060171919, 3.8545845272206236],
#  320.0: [31.46931407942239, 53.05054151624549, 10.940433212996396],
#  321.0: [16.18990536277603, 61.078233438485796, 20.08958990536277],
#  322.0: [8.038258038258036, 54.82539682539684, 14.921855921855922],
#  323.0: [6.504398826979468, 54.38269794721407, 30.13636363636364],
#  324.0: [12.892828999211972, 45.56816390858944, 43.5397951142632],
#  325.0: [6.118045112781957, 44.5, 36.87218045112782],
#  326.0: [30.524752475247524, 17.97821782178218, 49.871287128712865],
#  327.0: [40.25212181727409, 16.267099350973552, 49.90614078881677],
#  328.0: [40.23018867924529, 9.723270440251582, 43.607547169811326],
#  329.0: [40.96747967479675, -21.796747967479675, 3.0487804878048763],
#  330.0: [54.53587245349868, 0.81089459698849, -3.077502214348982],
#  331.0: [54.3567921440262, 1.0163666121112982, -13.157119476268413],
#  332.0: [56.22886866059818, -6.998699609882962, -8.472041612483743],
#  333.0: [48.06182795698925, -20.795698924731184, -8.13978494623656]}
